# %% [markdown]
# # DATA WRAGLING
# GROUP BY
# HANDLING MISSING DATA

# %% [markdown]
# * maping:
#     key value replacement
# * apply:
#      function is required
#
# * key can never b duplicated in a dictionary
#
# * slabs in data analytics are applied in series through cut kew cut

# %% [raw]
# Data wrangling is the process of cleaning, structuring and enriching raw data into a desired format for better decision making in less time. Data wrangling is increasingly ubiquitous at today’s top firms. Data has become more diverse and unstructured, demanding increased time spent culling, cleaning, and organizing data ahead of broader analysis.

# %%
DATA WRAGLING
  JOINING
    left_on
    right_on
    left_index_on
    right_index_on
    how(left,right,inner,out)

# %%
import pandas as pd
import numpy as np
df1=pd.DataFrame({'Customers NIC':np.random.randint(1,20,size=(20)),
                  'Cus Account':np.random.randint(1,5,size=(20))
                 })

# %%
df1.head(2)
# Out:
#    Customers NIC  Cus Account
# 0              6            4
# 1             13            3

# %%
df2=pd.DataFrame({'CNIC':np.random.randint(1,20,size=(20)),
                  'Account_NO':np.random.randint(1,2,size=(20)),
                  'Mobile no':np.random.randint(2001,3000,size=(20)),
                  'DOB':pd.date_range('1990-01-01',periods=20),
                  'Customer_Name':[chr(x) for x in np.random.randint(65,91,size=(20))],
                  'Gender':np.random.choice(['m','f'],size=20)
                 })

df2.head(10)
# Out:
#    CNIC  Account_NO  Mobile no        DOB Customer_Name Gender
# 0     4           1       2986 1990-01-01             P      f
# 1    14           1       2178 1990-01-02             Q      f
# 2    18           1       2339 1990-01-03             Z      m
# 3     1           1       2596 1990-01-04             M      f
# 4     7           1       2837 1990-01-05             B      m
# 5    17           1       2467 1990-01-06             K      m
# 6    17           1       2861 1990-01-07             D      m
# 7    14           1       2593 1990-01-08             F      m
# 8    10           1       2782 1990-01-09             U      f
# 9    16           1       2770 1990-01-10             G      f

# %%
[chr(x) for x in np.random.randint(65,91,size=(20))]
# Out:
# ['T',
#  'I',
#  'O',
#  'G',
#  'U',
#  'O',
#  'F',
#  'S',
#  'K',
#  'K',
#  'P',
#  'C',
#  'U',
#  'N',
#  'R',
#  'E',
#  'V',
#  'Z',
#  'X',
#  'E']

# %% [raw]
# For data wrangling data types of both the dfs should be same

# %%
print(df1.dtypes,'\n')
print(df2.dtypes)
# Out:
# Customers NIC    int32
# Cus Account      int32
# dtype: object
#
# CNIC                      int32
# Account_NO                int32
# Mobile no                 int32
# DOB              datetime64[ns]
# Customer_Name            object
# Gender                   object
# dtype: object

# %%
for c in df2.columns[:2]:
    print(c,len(df2[c].unique()))
    
#DROP DUPLICATE
# Out:
# CNIC 11
# Account_NO 1

# %%
df1.head(2)
# Out:
#    Customers NIC  Cus Account
# 0              6            4
# 1             13            3

# %%
df2.head(2)
# Out:
#    CNIC  Account_NO  Mobile no        DOB Customer_Name Gender
# 0     4           1       2986 1990-01-01             P      f
# 1    14           1       2178 1990-01-02             Q      f

# %%
    #left df      right df                  #the df written first will be on left
a = df1.merge(df2,on=['Customers NIC'],how='inner')  #on mein wouh column aata aa jisky base py merge krn gy,present in both 
                                            #with same dtypes
      
# inner join only common column, 
#outer , first same then add remaining 
#left 
#right

a = df1.merge(                                      )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-6b13cc553b80> in <module>
#       1 #left df      right df                  #the df written first will be on left
# ----> 2 a = df1.merge(df2,on=['Customers NIC'],how='inner')  #on mein wouh column aata aa jisky base py merge krn gy,present in both
#       3                                         #with same dtypes
#       4
#       5 # inner join only common column,
#
# ~\Anaconda3\anie\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7295             copy=copy,
#    7296             indicator=indicator,
# -> 7297             validate=validate,
#    7298         )
#    7299
#
# ...

# %%
a.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-4d0f5672653e> in <module>
# ----> 1 a.head()
#
# NameError: name 'a' is not defined

# %%
np.random.choice(['m','f'],size=20)
# Out:
# array(['m', 'f', 'm', 'm', 'f', 'm', 'f', 'm', 'm', 'f', 'm', 'm', 'm',
#        'f', 'f', 'f', 'm', 'f', 'f', 'f'], dtype='<U1')

# %%
a = df1.merge(df2,on=['CNIC','DOB'],how='inner')
a.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-680485d0c434> in <module>
# ----> 1 a = df1.merge(df2,on=['CNIC','DOB'],how='inner')
#
# ~\Anaconda3\anie\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7295             copy=copy,
#    7296             indicator=indicator,
# -> 7297             validate=validate,
#    7298         )
#    7299
#
# ~\Anaconda3\anie\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      84         copy=copy,
#      85         indicator=indicator,
# ---> 86         validate=validate,
#      87     )
#      88     return op.get_result()
#
# ...

# %%
a = df1.merge(df2,on=['CNIC','Account_NO'],how='left')
a.head()
# Out:
#    CNIC  Account_NO  Mobile no DOB Customer_Name Gender
# 0     7           4        NaN NaT           NaN    NaN
# 1     1           4        NaN NaT           NaN    NaN
# 2    12           4        NaN NaT           NaN    NaN
# 3    13           3        NaN NaT           NaN    NaN
# 4     8           3        NaN NaT           NaN    NaN

# %%
a = df1.merge(df2,on=['CNIC','Account_NO'],how='inner')
a.head()
# Out:
#    CNIC  Account_NO  Mobile no        DOB Customer_Name Gender
# 0     6           1       2313 1990-01-06             M      f
# 1     6           1       2391 1990-01-15             N      m
# 2     6           1       2313 1990-01-06             M      f
# 3     6           1       2391 1990-01-15             N      m

# %%
df1.drop_duplicates(["CNIC","Account_NO"])
# Out:
#     CNIC  Account_NO
# 0      7           4
# 1      1           4
# 2     12           4
# 3     13           3
# 4      8           3
# 5      3           4
# 6     11           3
# 7      1           3
# 8     11           2
# 9     16           2
# 10    16           1
# 11    18           3
# 12    17           2
# 13     9           3
# 14     5           2
# 15     6           1
# 16     7           3
# 19    14           4

# %%
df1=pd.DataFrame({'Customers NIC':np.random.randint(1,20,size=(20)),
                  'Cus Account':np.random.randint(1,5,size=(20))
                 })


df2=pd.DataFrame({'CNIC':np.random.randint(1,20,size=(20)),
                  'Account_NO':np.random.randint(1,2,size=(20)),
                  'Mobile no':np.random.randint(2001,3000,size=(20)),
                  'DOB':pd.date_range('1990-01-01',periods=20),
                  'Customer_Name':[chr(x) for x in np.random.randint(65,91,size=(20))],
                  'Gender':np.random.choice(['m','f'],size=20)
                 })

df2.head(10)

# %%
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6a861a8b3f1a> in <module>
# ----> 1 df1
#
# NameError: name 'df1' is not defined

# %%
df1.merge(df2,left_on=["Customers NIC",'Cus Account'],right_on=["CNIC","Account_NO"],how='inner')
# Out:
#    Customers NIC  Cus Account  CNIC  Account_NO  Mobile no        DOB  \
# 0              8            1     8           1       2020 1990-01-04
# 1              2            1     2           1       2309 1990-01-02
# 2              2            1     2           1       2639 1990-01-07
# 3             13            1    13           1       2265 1990-01-20
#
#   Customer_Name Gender
# 0             G      m
# 1             C      f
# 2             V      f
# 3             X      m

# %%
df1.merge(df2,left_on=["Customers NIC",'Cus Account'],right_on=["CNIC","Account_NO"],how='outer')
# Out:
#     Customers NIC  Cus Account  CNIC  Account_NO  Mobile no        DOB  \
# 0            10.0          3.0   NaN         NaN        NaN        NaT
# 1            11.0          3.0   NaN         NaN        NaN        NaT
# 2             7.0          3.0   NaN         NaN        NaN        NaT
# 3            17.0          1.0   NaN         NaN        NaN        NaT
# 4             5.0          1.0   NaN         NaN        NaN        NaT
# 5            15.0          4.0   NaN         NaN        NaN        NaT
# 6            19.0          4.0   NaN         NaN        NaN        NaT
# 7            19.0          4.0   NaN         NaN        NaN        NaT
# 8             4.0          2.0   NaN         NaN        NaN        NaT
# 9             3.0          2.0   NaN         NaN        NaN        NaT
# 10           13.0          4.0   NaN         NaN        NaN        NaT
# 11           16.0          4.0   NaN         NaN        NaN        NaT
# ...

# %% [raw]
# left/right on = ""
# left/right on = []

# %%
customers=pd.DataFrame({'Customers NIC':[14,6,10],
                  "Customer Name":["A","B","C"]
                 })

transactions=pd.DataFrame({'CNIC':np.random.choice([14,6,19,20,21],size=(20)),
                  'TRANSID':np.random.randint(1,2,size=(20)),
                  'TDATE':pd.date_range('1990-01-01',periods=20),
                  'Description':np.random.choice(['m','f'],size=20)
                 })




customers
# Out:
#    Customers NIC Customer Name
# 0             14             A
# 1              6             B
# 2             10             C

# %%
c=pd.DataFrame(transactions.CNIC.value_counts())

# %%
c.columns=["tr counts"]                           #group by
c
# Out:
#     tr counts
# 14          5
# 21          4
# 19          4
# 6           4
# 20          3

# %% [raw]
# join based on left column and right index

# %%
customers.merge(c,left_on="Customers NIC",right_index=True,how='left')
# Out:
#    Customers NIC Customer Name  tr counts
# 0             14             A        5.0
# 1              6             B        4.0
# 2             10             C        NaN

# %%
customers.merge(c,left_on="Customers NIC",right_index=True,how='right')
# Out:
#      Customers NIC Customer Name  tr counts
# 0.0             14             A          5
# 1.0              6             B          4
# NaN             21           NaN          4
# NaN             19           NaN          4
# NaN             20           NaN          3

# %%
customers.join(c,on="Customers NIC",how='right')
# Out:
#      Customers NIC Customer Name  tr counts
# 0.0             14             A          5
# 1.0              6             B          4
# NaN             21           NaN          4
# NaN             19           NaN          4
# NaN             20           NaN          3

# %% [raw]
# join first df k sath dosery df
# merge mein aik se zaida columns aa skty hein

# %%
pd.merge??

# %%
df1=pd.DataFrame({'Customers NIC':np.random.randint(1,20,size=(20)),
                  'Cus Account':np.random.randint(1,5,size=(20))
                 })


df2=pd.DataFrame({'CNIC':np.random.randint(1,20,size=(20)),
                  'Account_NO':np.random.randint(1,2,size=(20)),
                  'Mobile no':np.random.randint(2001,3000,size=(20)),
                  'DOB':pd.date_range('1990-01-01',periods=20),
                  'Customer_Name':[chr(x) for x in np.random.randint(65,91,size=(20))],
                  'Gender':np.random.choice(['m','f'],size=20)
                 })

a=df1.join(df2,on="Customers NIC",how='right',lsuffix="left",rsuffix="right")

# %%
a
# Out:
#       Customers NIC  Cus Account  CNIC  Account_NO  Mobile no        DOB  \
# 0.0              11          4.0     4           1       2146 1990-01-12
# 7.0              11          3.0     4           1       2146 1990-01-12
# 17.0             11          2.0     4           1       2146 1990-01-12
# 1.0               5          4.0     6           1       2058 1990-01-06
# 13.0              5          3.0     6           1       2058 1990-01-06
# 2.0               8          3.0     5           1       2644 1990-01-09
# 5.0               8          4.0     5           1       2644 1990-01-09
# 18.0              8          2.0     5           1       2644 1990-01-09
# 3.0              10          1.0    17           1       2436 1990-01-11
# 14.0             10          1.0    17           1       2436 1990-01-11
# 4.0               4          2.0     8           1       2145 1990-01-05
# 6.0              13          3.0    14           1       2602 1990-01-14
# ...

# %%
df1=pd.DataFrame({"NIC":[1,2,4],"A":[1,3,23]})
df2=pd.DataFrame({"NIC":[1,2,3],"B":[1,3,23]})
df3=pd.DataFrame({"NIC":[1,4,7],"C":[1,3,23]})
df=df1.merge(df2,on="NIC",how="left")
df=df.merge(df3,on="NIC",how="left")

# %%
df
# Out:
#    NIC   A    B    C
# 0    1   1  1.0  1.0
# 1    2   3  3.0  NaN
# 2    4  23  NaN  3.0

# %%
df1=pd.DataFrame({"NIC":[1,2,4],"A":[1,3,23]})
df2=pd.DataFrame({"NIC":[1,2,3],"B":[1,3,23]})
df3=pd.DataFrame({"NIC":[1,4,7],"C":[1,3,23]})
df=df1.merge(df2,on="NIC",how="left").merge(df3,on="NIC",how="left")

# %%
df
# Out:
#    NIC   A    B    C
# 0    1   1  1.0  1.0
# 1    2   3  3.0  NaN
# 2    4  23  NaN  3.0

# %% [markdown]
# # GROUP BY

# %% [markdown]
# * UNSTACK
# * RESET_INDEX()
# * PIVOT_TABLE()

# %% [raw]
# Group by applies any function on a particular set of data on a single column or multiple column

# %%
df2=pd.DataFrame({'CNIC':np.random.randint(1,20,size=(20)),
                  'Account_NO':np.random.randint(1,2,size=(20)),
                  'Mobile no':np.random.randint(2001,3000,size=(20)),
                  'DOB':pd.date_range('1990-01-01',periods=20),
                  'Customer_Name':[chr(x) for x in np.random.randint(65,91,size=(20))],
                  'Gender':np.random.choice(['m','f'],size=20)
                 })

# %%
df2.head()
# Out:
#    CNIC  Account_NO  Mobile no        DOB Customer_Name Gender
# 0     7           1       2977 1990-01-01             E      m
# 1     7           1       2907 1990-01-02             U      f
# 2     9           1       2085 1990-01-03             I      f
# 3    12           1       2396 1990-01-04             V      f
# 4    13           1       2768 1990-01-05             D      m

# %%
df2.groupby(by="Gender").agg(['count'])
# Out:
#         CNIC Account_NO Mobile no   DOB Customer_Name
#        count      count     count count         count
# Gender
# f          6          6         6     6             6
# m         14         14        14    14            14

# %%
df2.sort_values(by=["Gender"])
# Out:
#     CNIC  Account_NO  Mobile no        DOB Customer_Name Gender
# 0     17           1       2132 1990-01-01             J      f
# 16    19           1       2943 1990-01-17             P      f
# 15    19           1       2882 1990-01-16             H      f
# 14     7           1       2796 1990-01-15             A      f
# 18    14           1       2323 1990-01-19             B      f
# 19    14           1       2810 1990-01-20             G      f
# 4     15           1       2483 1990-01-05             T      f
# 5      9           1       2164 1990-01-06             S      f
# 6     13           1       2161 1990-01-07             L      m
# 7     15           1       2504 1990-01-08             I      m
# 8      8           1       2208 1990-01-09             S      m
# 10     6           1       2415 1990-01-11             G      m
# 11    11           1       2942 1990-01-12             P      m
# 12    12           1       2031 1990-01-13             K      m
# ...
